# %%
import sys
import pandas as pd
import datetime
import csv

# %%
antennas_unique = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/ProcessamentoVinicius/Jf/antennas_jf_unique.txt', sep=';')
antennas_unique = antennas_unique.loc[antennas_unique['MUNICIPALITY'] == 'Microrregião Juiz de Fora']
len(antennas_unique.groupby(['LAT', 'LONG']))
# Out:
# 67

# %%
antennas_unique
# Out:
#     CELLID  UF  DDD       LAT      LONG              CITY  \
# 1    29922  MG   32 -21.77560 -43.43085      Juiz de Fora
# 2    29953  MG   32 -21.79245 -43.38823      Juiz de Fora
# 3    23733  MG   32 -21.78109 -43.36022      Juiz de Fora
# 4    51492  MG   32 -21.72198 -43.40184      Juiz de Fora
# 5    23723  MG   32 -21.77572 -43.34728      Juiz de Fora
# ..     ...  ..  ...       ...       ...               ...
# 63   51052  MG   32 -21.58390 -43.46778      Juiz de Fora
# 64   50341  MG   32 -21.78027 -43.29190      Juiz de Fora
# 65   50563  MG   32 -21.63227 -43.45291      Juiz de Fora
# 66   50542  MG   32 -21.53686 -43.50584  Ewbank da Câmara
# 67   51302  MG   32 -21.36232 -43.57716     Santos Dumont
#
#                  MUNICIPALITY
# 1   Microrregião Juiz de Fora
# 2   Microrregião Juiz de Fora
# 3   Microrregião Juiz de Fora
# 4   Microrregião Juiz de Fora
# 5   Microrregião Juiz de Fora
# ..                        ...
# 63  Microrregião Juiz de Fora
# ...

# %%
def get_trajectory_by_user(cdr_filtered):
    for df_cdr in pd.read_csv(cdr_filtered, sep=';', iterator=True, chunksize=1000000):
        df_cdr_grouped_user_antenna =
