# %%
import pandas as pd

# %%
df = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/antenas/antennas_municipality.txt', sep=';')
df.rename(columns={'CELLID': 'ANTENNA'}, inplace=True)
df.head()
# Out:
#    ANTENNA  UF  DDD       LAT      LONG             CITY  \
# 0    27823  RJ   21 -22.82638 -43.32344   Rio de Janeiro
# 1    27852  RJ   21 -22.82638 -43.32344   Rio de Janeiro
# 2    60097  AC   68  -7.63047 -72.66910  Cruzeiro do Sul
# 3    20109  AC   68  -9.97669 -67.86836       Rio Branco
# 4    20237  AC   68  -9.97197 -67.81339       Rio Branco
#
#                                    MUNICIPALITY
# 0  Região Geográfica Imediata do Rio de Janeiro
# 1  Região Geográfica Imediata do Rio de Janeiro
# 2               Microrregião de Cruzeiro do Sul
# 3      Região Geográfica Imediata de Rio Branco
# 4      Região Geográfica Imediata de Rio Branco

# %%
cities_jf = ['Andrelândia', 'Aracitaba', 'Arantina', 'Belmiro', 'Braga', 'Bias Fortes', 'Bocaina de Minas',
             'Bom Jardim de Minas', 'Chácara', 'Chiador', 'Coronel Pacheco', 'Ewbank da Câmara', 'Goianá', 
             'Juiz de Fora', 'Liberdade', 'Lima Duarte', 'Matias Barbosa', 'Olaria', 'Oliveira Fortes', 
             'Paiva', 'Passa Vinte', 'Pedro Teixeira', 'Piau', 'Rio Novo', 'Rio Preto', 'Santa Bárbara do Monte Verde',
             'Santa Rita de Jacutinga', 'Santana do Deserto', 'Santos Dumont', 'Simão Pereira']

# %%
df = df.loc[df['CITY'].isin(cities_jf)]
df
# Out:
#        ANTENNA  UF  DDD       LAT      LONG            CITY  \
# 4030     17178  MA   98  -3.60925 -45.34292   Santos Dumont
# 4273     29922  MG   32 -21.77560 -43.43085    Juiz de Fora
# 4306     29953  MG   32 -21.79245 -43.38823    Juiz de Fora
# 4396     23733  MG   32 -21.78109 -43.36022    Juiz de Fora
# 4397     51492  MG   32 -21.72198 -43.40184    Juiz de Fora
# ...        ...  ..  ...       ...       ...             ...
# 64747    50791  MG   32 -21.66369 -43.43173    Juiz de Fora
# 64748    50882  MG   32 -21.78162 -43.34295    Juiz de Fora
# 64749    50883  MG   32 -21.78162 -43.34295    Juiz de Fora
# 64750    65771  MG   32 -21.67006 -43.43436    Juiz de Fora
# 64793    50613  MG   32 -21.87465 -43.33599  Matias Barbosa
#
#                     MUNICIPALITY
# 4030     Microrregião de Pindaré
# 4273   Microrregião Juiz de Fora
# 4306   Microrregião Juiz de Fora
# 4396   Microrregião Juiz de Fora
# 4397   Microrregião Juiz de Fora
# ...                          ...
# ...

# %%
df = df.groupby(['LAT', 'LONG', 'CITY']).first().reset_index()
# Out:
# array(['Braga', 'Matias Barbosa', 'Lima Duarte', 'Juiz de Fora',
#        'Ewbank da Câmara', 'Goianá', 'Rio Novo', 'Santos Dumont'],
#       dtype=object)

# %%
df_1 = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/dados_18.11/cdr/JF_Filter_by_duration/df_1.csv', nrows=1000000)
df_1
# Out:
#         Unnamed: 0        DATE      HOUR  DURATION  DDD_USER_FROM  \
# 0                0  2013-03-21  18:55:11      1.63             32
# 1                1  2013-03-21  19:45:36      0.07             32
# 2                2  2013-03-21  13:56:03     14.58             32
# 3                3  2013-03-21  14:55:45      2.98             83
# 4                4  2013-03-21  19:08:59      0.08             83
# ...            ...         ...       ...       ...            ...
# 999995     1009973  2013-03-21  22:38:27      0.08             32
# 999996     1009974  2013-03-21  09:11:38      1.18             32
# 999997     1009975  2013-03-21  06:36:39      0.13             32
# 999998     1009976  2013-03-21  23:09:43      0.08             32
# 999999     1009977  2013-03-21  12:08:47      0.50             32
#
#                                USER_FROM  DDD_USER_TO  \
# 0       54099B93776E46FDD92355B4BC73286C           -4
# 1       4337363045DA84F1AC27CE94BC1462C3           32
# ...

# %%
df_1.drop(columns={'Unnamed: 0'}, inplace=True)
df_1 = pd.merge(df_1, df[['ANTENNA', 'LAT', 'LONG', 'CITY']], on='ANTENNA')

# %%
df_1['CITY'].unique()
# Out:
# array(['Volta Redonda', 'Juiz de Fora', 'Maceió', 'Macapá', 'Ibema',
#        'Rio de Janeiro', 'Santos Dumont', 'Santa Rita', 'Bayeux',
#        'Lima Duarte', 'Taperoá', 'Vitória do Xingu', 'Resende',
#        'Padre Bernardo', 'Altamira', 'Campos dos Goytacazes', 'Macaé',
#        'Santa Maria do Pará', 'Santarém', 'Salvador', 'Fortaleza',
#        'unknown', 'Itatiaia', 'Paripueira', 'Abaetetuba',
#        'Águas Lindas de Goiás', 'Formosa', 'Patos', 'Matias Barbosa',
#        'Rio Largo', 'Aragarças', 'Baião', 'Cristalina', 'Guarabira',
#        'Campo Bonito', 'Aquidabã', 'Arraias', 'Campina Grande',
#        'Cajazeiras', 'Santo Antônio do Descoberto', "São João d'Aliança",
#        'Santana', 'Belterra', 'Quixaba', 'Luziânia', 'Cidade Ocidental',
#        'Braganey', 'Ewbank da Câmara', 'Mamanguape', 'Monte Alegre',
#        'Panambi', 'Goianá', 'Ouro Verde do Oeste', 'Novo Gama', 'Acará',
#        'Barra do Piraí', 'Conde', 'Rio Novo', 'Itápolis'], dtype=object)
