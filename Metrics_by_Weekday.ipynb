# %%
import pandas as pd

# %% [markdown]
# # Lendo os dataframes por dia de semana

# %%
df_monday = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/CDR_by_day_of_week/cdr_monday.csv')
df_monday = df_monday.drop('Unnamed: 0', 1)
df_monday.head()
# Out:
#          DATE      HOUR  DURATION  DDD_USER_FROM  \
# 0  2013-03-25  19:13:00      0.07             32
# 1  2013-03-25  21:32:58      0.48             61
# 2  2013-03-25  15:03:31      2.88             32
# 3  2013-03-25  09:55:19      0.23             61
# 4  2013-03-25  13:31:52      3.68             32
#
#                           USER_FROM  DDD_USER_TO  \
# 0  6DE5DFDBD31D50256FF9D7BD55B111C1           32
# 1  B046BF714E16102B098297E89639BA30           61
# 2  8EC44C0732041BCC3FA715DB9A4F9FF8           32
# 3  7E50C43F7BFCAD3E9F0B5EDD00F59E72           61
# 4  3516DCA64295745DB7C323B3F874DB2B           32
#
#                             USER_TO  ANTENNA    9     10   11   12        13  \
# 0  3017748B03D2CD346C8562616DE59920    50141  117  LOCAL   OI   OI  POS PAGO
# 1  A943CD0FB95D587FF5D10F61D643AD73    51601  117  LOCAL  BRT  BRT  PRE PAGO
# 2  345919C0A53C482A17225635C23AE7B6    50141  117  LOCAL   OI   OI  PRE PAGO
# ...

# %%
df_final = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/travelled_distance/df_final.csv')
df_final = df_final.drop('Unnamed: 0', 1)
df_final.sample(5)
# Out:
#                                    USER PRESUMED_RESIDENCE  \
# 33084  8E1953151F877A3348D4CAB4B2B0C7A8              SJDR5
# 25303  6CC988C537A34919103D0070F77F354A                SVM
# 54902  EB6B518E418048ABEA9437F916E697C0              SJDR1
# 6130   1A783D41214D35F05CFA808F77F4E9B7              SJDR1
# 9832   2A59649D7751E968BDE4747DFC174E47                 RT
#
#                                                 CALL_LOC  TRAVELLED_DISTANCE
# 33084  ['SJDR5', 'SJDR5', 'SJDR5', 'SJDR5', 'SJDR5', ...              0.0000
# 25303              ['SVM', 'SVM', 'SVM', 'SVM', 'SJDR4']             66.6074
# 54902                        ['SJDR1', 'SJDR1', 'SJDR1']              0.0000
# 6130                                           ['SJDR1']              0.0000
# 9832                ['RT', 'RT', 'RT', 'RT', 'RT', 'RT']              0.0000

# %%
df_final_monday = df_final[df_final.USER.isin(df_monday.USER_FROM)]
df_final_monday.head()
# Out:
#                                USER PRESUMED_RESIDENCE  \
# 0  00003F26576D1122848B6F3CEEC250E5              SJDR5
# 1  000579E8BA1DA9E5292392473BCCCD2A                LD1
# 2  0008962B966EF6C5571DF03F5C786677              SJDR2
# 3  0008B7FB336065A53EC31AD06D712E28                 RT
# 4  0008B8E32E18BF4450B7CAAF0C1CE179              SJDR1
#
#                                             CALL_LOC  TRAVELLED_DISTANCE
# 0      ['SJDR5', 'SJDR5', 'SJDR5', 'SJDR5', 'SJDR5']                 0.0
# 1  ['LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1']                 0.0
# 2  ['SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', ...                 0.0
# 3   ['RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT']                 0.0
# 4  ['SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', ...                 0.0

# %%
df_tuesday = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/CDR_by_day_of_week/cdr_tuesday.csv')
df_tuesday = df_tuesday.drop('Unnamed: 0', 1)
df_tuesday.head()
# Out:
#          DATE      HOUR  DURATION  DDD_USER_FROM  \
# 0  2013-03-26  10:04:49      1.13             61
# 1  2013-03-26  15:22:57     12.23             32
# 2  2013-03-26  22:39:42      0.13             61
# 3  2013-03-26  13:42:33      1.35             61
# 4  2013-03-26  12:30:37      1.45             61
#
#                           USER_FROM  DDD_USER_TO  \
# 0  BA4DEA1F710C1216F74F1255150C49D6           61
# 1  48E47220BE06E60C6C46112A89380F81           32
# 2  C552B81B006814EFC7596F121FA7947E           61
# 3  C552B81B006814EFC7596F121FA7947E           61
# 4  023CF68D76C38796F6C3B138F27AC657           61
#
#                             USER_TO  ANTENNA    9     10   11   12        13  \
# 0  7992B62B0D739809A33C8A605D2308BE    51601  117  LOCAL  BRT  BRT  PRE PAGO
# 1  E7FE9A22107573C4FEEBA7E11C377DDA    50141   77  LOCAL   OI  TNL  POS PAGO
# 2  D3E95A41C56E8596A019C2DF0C1DF66B    51601  117  LOCAL  BRT  BRT  PRE PAGO
# ...

# %%
df_final_tuesday = df_final[df_final.USER.isin(df_tuesday.USER_FROM)]
df_final_tuesday.head()
# Out:
#                                USER PRESUMED_RESIDENCE  \
# 0  00003F26576D1122848B6F3CEEC250E5              SJDR5
# 1  000579E8BA1DA9E5292392473BCCCD2A                LD1
# 2  0008962B966EF6C5571DF03F5C786677              SJDR2
# 4  0008B8E32E18BF4450B7CAAF0C1CE179              SJDR1
# 5  0008B94CADE67ACABE2CB3F8DB477CC5                LD1
#
#                                             CALL_LOC  TRAVELLED_DISTANCE
# 0      ['SJDR5', 'SJDR5', 'SJDR5', 'SJDR5', 'SJDR5']                 0.0
# 1  ['LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1']                 0.0
# 2  ['SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', ...                 0.0
# 4  ['SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', ...                 0.0
# 5                                            ['LD1']                 0.0

# %%
df_wednesday = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/CDR_by_day_of_week/cdr_wednesday.csv')
df_wednesday = df_wednesday.drop('Unnamed: 0', 1)

df_final_wednesday = df_final[df_final.USER.isin(df_wednesday.USER_FROM)]
df_final_wednesday.head()
# Out:
#                                USER PRESUMED_RESIDENCE  \
# 0  00003F26576D1122848B6F3CEEC250E5              SJDR5
# 1  000579E8BA1DA9E5292392473BCCCD2A                LD1
# 2  0008962B966EF6C5571DF03F5C786677              SJDR2
# 3  0008B7FB336065A53EC31AD06D712E28                 RT
# 4  0008B8E32E18BF4450B7CAAF0C1CE179              SJDR1
#
#                                             CALL_LOC  TRAVELLED_DISTANCE
# 0      ['SJDR5', 'SJDR5', 'SJDR5', 'SJDR5', 'SJDR5']                 0.0
# 1  ['LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1']                 0.0
# 2  ['SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', ...                 0.0
# 3   ['RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT']                 0.0
# 4  ['SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', ...                 0.0

# %%
df_thursday = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/CDR_by_day_of_week/cdr_thursday.csv')
df_thursday = df_thursday.drop('Unnamed: 0', 1)

df_final_thursday = df_final[df_final.USER.isin(df_thursday.USER_FROM)]
df_final_thursday.head()
# Out:
#                                USER PRESUMED_RESIDENCE  \
# 0  00003F26576D1122848B6F3CEEC250E5              SJDR5
# 1  000579E8BA1DA9E5292392473BCCCD2A                LD1
# 2  0008962B966EF6C5571DF03F5C786677              SJDR2
# 3  0008B7FB336065A53EC31AD06D712E28                 RT
# 4  0008B8E32E18BF4450B7CAAF0C1CE179              SJDR1
#
#                                             CALL_LOC  TRAVELLED_DISTANCE
# 0      ['SJDR5', 'SJDR5', 'SJDR5', 'SJDR5', 'SJDR5']                 0.0
# 1  ['LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1']                 0.0
# 2  ['SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', ...                 0.0
# 3   ['RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT']                 0.0
# 4  ['SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', ...                 0.0

# %%
df_friday = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/CDR_by_day_of_week/cdr_friday.csv')
df_friday = df_friday.drop('Unnamed: 0', 1)

df_final_friday = df_final[df_final.USER.isin(df_friday.USER_FROM)]
df_final_friday.head()
# Out:
#                                USER PRESUMED_RESIDENCE  \
# 0  00003F26576D1122848B6F3CEEC250E5              SJDR5
# 1  000579E8BA1DA9E5292392473BCCCD2A                LD1
# 2  0008962B966EF6C5571DF03F5C786677              SJDR2
# 3  0008B7FB336065A53EC31AD06D712E28                 RT
# 4  0008B8E32E18BF4450B7CAAF0C1CE179              SJDR1
#
#                                             CALL_LOC  TRAVELLED_DISTANCE
# 0      ['SJDR5', 'SJDR5', 'SJDR5', 'SJDR5', 'SJDR5']                 0.0
# 1  ['LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1']                 0.0
# 2  ['SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', ...                 0.0
# 3   ['RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT']                 0.0
# 4  ['SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', ...                 0.0

# %%
df_saturday = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/CDR_by_day_of_week/cdr_saturday.csv')
df_saturday = df_saturday.drop('Unnamed: 0', 1)

df_final_saturday = df_final[df_final.USER.isin(df_saturday.USER_FROM)]
df_final_saturday.head()
# Out:
#                                USER PRESUMED_RESIDENCE  \
# 0  00003F26576D1122848B6F3CEEC250E5              SJDR5
# 1  000579E8BA1DA9E5292392473BCCCD2A                LD1
# 2  0008962B966EF6C5571DF03F5C786677              SJDR2
# 3  0008B7FB336065A53EC31AD06D712E28                 RT
# 4  0008B8E32E18BF4450B7CAAF0C1CE179              SJDR1
#
#                                             CALL_LOC  TRAVELLED_DISTANCE
# 0      ['SJDR5', 'SJDR5', 'SJDR5', 'SJDR5', 'SJDR5']                 0.0
# 1  ['LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1']                 0.0
# 2  ['SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', ...                 0.0
# 3   ['RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT', 'RT']                 0.0
# 4  ['SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', ...                 0.0

# %%
df_sunday = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/CDR_by_day_of_week/cdr_sunday.csv')
df_sunday = df_sunday.drop('Unnamed: 0', 1)

df_final_sunday = df_final[df_final.USER.isin(df_sunday.USER_FROM)]
df_final_sunday.head()
# Out:
#                                USER PRESUMED_RESIDENCE  \
# 0  00003F26576D1122848B6F3CEEC250E5              SJDR5
# 1  000579E8BA1DA9E5292392473BCCCD2A                LD1
# 2  0008962B966EF6C5571DF03F5C786677              SJDR2
# 4  0008B8E32E18BF4450B7CAAF0C1CE179              SJDR1
# 5  0008B94CADE67ACABE2CB3F8DB477CC5                LD1
#
#                                             CALL_LOC  TRAVELLED_DISTANCE
# 0      ['SJDR5', 'SJDR5', 'SJDR5', 'SJDR5', 'SJDR5']                 0.0
# 1  ['LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1', 'LD1']                 0.0
# 2  ['SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', 'SJDR2', ...                 0.0
# 4  ['SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', 'SJDR1', ...                 0.0
# 5                                            ['LD1']                 0.0

# %%
import nbimporter
import Functions

result_monday = Functions.position_measures(df_final_monday)
result_tuesday = Functions.position_measures(df_final_tuesday)
result_wednesday = Functions.position_measures(df_final_wednesday)
result_thursday = Functions.position_measures(df_final_thursday)
result_friday = Functions.position_measures(df_final_friday)
result_saturday = Functions.position_measures(df_final_saturday)
result_sunday = Functions.position_measures(df_final_sunday)
# Out:
# Importing Jupyter notebook from Functions.ipynb

# %%
result_monday = Functions.normalization_values(result_monday)
result_tuesday = Functions.normalization_values(result_tuesday)
result_wednesday = Functions.normalization_values(result_wednesday)
result_thursday = Functions.normalization_values(result_thursday)
result_friday = Functions.normalization_values(result_friday)
result_saturday = Functions.normalization_values(result_saturday)
result_sunday = Functions.normalization_values(result_sunday)

# %%
import matplotlib.pyplot as plt

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()

# %%
x = np.arange(len(result_monday))
width = 1

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_monday.index.values)


rects1 = ax.bar(x + 0.4, result_monday.HIGHER_MEAN, width/10, label='MONDAY')
rects2 = ax.bar(x + 0.3, result_tuesday.HIGHER_MEAN, width/10, label='TUESDAY')
rects3 = ax.bar(x + 0.2, result_wednesday.HIGHER_MEAN, width/10, label='WEDNESDAY')
rects4 = ax.bar(x + 0.1, result_thursday.HIGHER_MEAN, width/10, label='THURSDAY')
rects5 = ax.bar(x, result_friday.HIGHER_MEAN, width/10, label='FRIDAY')
rects6 = ax.bar(x - 0.1, result_saturday.HIGHER_MEAN, width/10, label='SATURDAY')
rects7 = ax.bar(x - 0.2, result_sunday.HIGHER_MEAN, width/10, label='SUNDAY')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)
autolabel(rects6)
autolabel(rects7)


plt.legend()
plt.title('Mean Distance Travelled by region by weekday - HIGHER MEAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/higher_mean.png')

# %%
x = np.arange(len(result_monday))
width = 1

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_monday.index.values)


rects1 = ax.bar(x + 0.4, result_monday.LOWER_MEAN, width/10, label='MONDAY')
rects2 = ax.bar(x + 0.3, result_tuesday.LOWER_MEAN, width/10, label='TUESDAY')
rects3 = ax.bar(x + 0.2, result_wednesday.LOWER_MEAN, width/10, label='WEDNESDAY')
rects4 = ax.bar(x + 0.1, result_thursday.LOWER_MEAN, width/10, label='THURSDAY')
rects5 = ax.bar(x, result_friday.LOWER_MEAN, width/10, label='FRIDAY')
rects6 = ax.bar(x - 0.1, result_saturday.LOWER_MEAN, width/10, label='SATURDAY')
rects7 = ax.bar(x - 0.2, result_sunday.LOWER_MEAN, width/10, label='SUNDAY')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)
autolabel(rects6)
autolabel(rects7)


plt.legend()
plt.title('Mean Distance Travelled by region by weekday - LOWER MEAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/lower_mean.png')

# %%
x = np.arange(len(result_monday))
width = 1

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_monday.index.values)


rects1 = ax.bar(x + 0.4, result_monday.LOWER_MEDIAN, width/10, label='MONDAY')
rects2 = ax.bar(x + 0.3, result_tuesday.LOWER_MEDIAN, width/10, label='TUESDAY')
rects3 = ax.bar(x + 0.2, result_wednesday.LOWER_MEDIAN, width/10, label='WEDNESDAY')
rects4 = ax.bar(x + 0.1, result_thursday.LOWER_MEDIAN, width/10, label='THURSDAY')
rects5 = ax.bar(x, result_friday.LOWER_MEDIAN, width/10, label='FRIDAY')
rects6 = ax.bar(x - 0.1, result_saturday.LOWER_MEDIAN, width/10, label='SATURDAY')
rects7 = ax.bar(x - 0.2, result_sunday.LOWER_MEDIAN, width/10, label='SUNDAY')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)
autolabel(rects6)
autolabel(rects7)


plt.legend()
plt.title('Median of Distance Travelled by region by weekday - LOWER MEDIAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/lower_median.jpg')

# %%
x = np.arange(len(result_monday))
width = 1

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_monday.index.values)


rects1 = ax.bar(x + 0.4, result_monday.HIGHER_MEDIAN, width/10, label='MONDAY')
rects2 = ax.bar(x + 0.3, result_tuesday.HIGHER_MEDIAN, width/10, label='TUESDAY')
rects3 = ax.bar(x + 0.2, result_wednesday.HIGHER_MEDIAN, width/10, label='WEDNESDAY')
rects4 = ax.bar(x + 0.1, result_thursday.HIGHER_MEDIAN, width/10, label='THURSDAY')
rects5 = ax.bar(x, result_friday.HIGHER_MEDIAN, width/10, label='FRIDAY')
rects6 = ax.bar(x - 0.1, result_saturday.HIGHER_MEDIAN, width/10, label='SATURDAY')
rects7 = ax.bar(x - 0.2, result_sunday.HIGHER_MEDIAN, width/10, label='SUNDAY')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)
autolabel(rects6)
autolabel(rects7)


plt.legend()
plt.title('Median of Distance Travelled by region by weekday - HIGHER MEDIAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/higher_median.png')

# %%
x = np.arange(len(result_monday))
width = 1

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_monday.index.values)


rects1 = ax.bar(x + 0.4, result_monday.HIGHER_STD, width/10, label='MONDAY')
rects2 = ax.bar(x + 0.3, result_tuesday.HIGHER_STD, width/10, label='TUESDAY')
rects3 = ax.bar(x + 0.2, result_wednesday.HIGHER_STD, width/10, label='WEDNESDAY')
rects4 = ax.bar(x + 0.1, result_thursday.HIGHER_STD, width/10, label='THURSDAY')
rects5 = ax.bar(x, result_friday.HIGHER_STD, width/10, label='FRIDAY')
rects6 = ax.bar(x - 0.1, result_saturday.HIGHER_STD, width/10, label='SATURDAY')
rects7 = ax.bar(x - 0.2, result_sunday.HIGHER_STD, width/10, label='SUNDAY')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)
autolabel(rects6)
autolabel(rects7)


plt.legend()
plt.title('STD of Distance Travelled by region by weekday - HIGHER STD')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/higher_std.png')

# %%
x = np.arange(len(result_monday))
width = 1

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_monday.index.values)


rects1 = ax.bar(x + 0.4, result_monday.LOWER_STD, width/10, label='MONDAY')
rects2 = ax.bar(x + 0.3, result_tuesday.LOWER_STD, width/10, label='TUESDAY')
rects3 = ax.bar(x + 0.2, result_wednesday.LOWER_STD, width/10, label='WEDNESDAY')
rects4 = ax.bar(x + 0.1, result_thursday.LOWER_STD, width/10, label='THURSDAY')
rects5 = ax.bar(x, result_friday.LOWER_STD, width/10, label='FRIDAY')
rects6 = ax.bar(x - 0.1, result_saturday.LOWER_STD, width/10, label='SATURDAY')
rects7 = ax.bar(x - 0.2, result_sunday.LOWER_STD, width/10, label='SUNDAY')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)
autolabel(rects6)
autolabel(rects7)


plt.legend()
plt.title('STD of Distance Travelled by region by weekday - LOWER STD')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/lower_std.png')

# %%
def calls_of_day(df):
    cdr_day = df[(df.HOUR.between('06:00:00', '18:59:59'))]
    return cdr_day

# %%
df_monday_day = calls_of_day(df_monday)
df_tuesday_day = calls_of_day(df_tuesday)
df_wednesady_day = calls_of_day(df_wednesday)
df_thursday_day = calls_of_day(df_thursday)
df_friday_day = calls_of_day(df_friday)
df_saturday_day = calls_of_day(df_saturday)

# %%
def df_with_distance(df):
    df2 = df_final[df_final.USER.isin(df.USER_FROM)]
    return df2

# %%
result_monday_day = df_with_distance(df_monday_day)
result_tuesday_day = df_with_distance(df_tuesday_day)
result_wednesday_day = df_with_distance(df_wednesady_day)
result_thursday_day = df_with_distance(df_thursday_day)
result_friday_day = df_with_distance(df_friday_day)
result_saturday_day = df_with_distance(df_saturday_day)

# %%
result_monday_day = Functions.position_measures(result_monday_day)
result_tuesday_day = Functions.position_measures(result_tuesday_day)
result_wednesday_day = Functions.position_measures(result_wednesday_day)
result_thursday_day = Functions.position_measures(result_thursday_day)
result_friday_day = Functions.position_measures(result_friday_day)
result_saturday_day = Functions.position_measures(result_saturday_day)

# %%
result_monday_day = Functions.normalization_values(result_monday_day)
result_tuesday_day = Functions.normalization_values(result_tuesday_day)
result_wednesday_day = Functions.normalization_values(result_wednesday_day)
result_thursday_day = Functions.normalization_values(result_thursday_day)
result_friday_day = Functions.normalization_values(result_friday_day)
result_saturday_day = Functions.normalization_values(result_saturday_day)

# %%
x = np.arange(len(result_monday_day))
width = 1

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_monday_day.index.values)


rects1 = ax.bar(x + 0.4, result_monday_day.HIGHER_MEAN, width/10, label='MONDAY')
rects2 = ax.bar(x + 0.3, result_tuesday_day.HIGHER_MEAN, width/10, label='TUESDAY')
rects3 = ax.bar(x + 0.2, result_wednesday_day.HIGHER_MEAN, width/10, label='WEDNESDAY')
rects4 = ax.bar(x + 0.1, result_thursday_day.HIGHER_MEAN, width/10, label='THURSDAY')
rects5 = ax.bar(x, result_friday_day.HIGHER_MEAN, width/10, label='FRIDAY')
rects6 = ax.bar(x - 0.1, result_saturday_day.HIGHER_MEAN, width/10, label='SATURDAY')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)
autolabel(rects6)


plt.legend()
plt.title('Mean Distance Travelled by region by weekday during business hour - HIGHER MEAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/higher_mean_bh.png')

# %%
x = np.arange(len(result_monday_day))
width = 1

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_monday_day.index.values)


rects1 = ax.bar(x + 0.4, result_monday_day.LOWER_MEAN, width/10, label='MONDAY')
rects2 = ax.bar(x + 0.3, result_tuesday_day.LOWER_MEAN, width/10, label='TUESDAY')
rects3 = ax.bar(x + 0.2, result_wednesday_day.LOWER_MEAN, width/10, label='WEDNESDAY')
rects4 = ax.bar(x + 0.1, result_thursday_day.LOWER_MEAN, width/10, label='THURSDAY')
rects5 = ax.bar(x, result_friday_day.LOWER_MEAN, width/10, label='FRIDAY')
rects6 = ax.bar(x - 0.1, result_saturday_day.LOWER_MEAN, width/10, label='SATURDAY')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)
autolabel(rects6)


plt.legend()
plt.title('Mean Distance Travelled by region by weekday during business hour - LOWER MEAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/lower_mean_bh.png')

# %%
df_general = pd.read_csv('/home/gustavo/Desktop/Mestrado/mestrado_dados/dados_18.11/cdr_after_filtes.csv')

# %%
week_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
weekend_days = ['Saturday', 'Monday']

df_week_days = df_general[df_general.DAY_OF_WEEK.isin(week_days)]
df_week_days = df_week_days.drop('Unnamed: 0', 1)

df_weekend_days = df_general[df_general.DAY_OF_WEEK.isin(weekend_days)]
df_weekend_days_days = df_weekend_days_days.drop('Unnamed: 0', 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-87d7832f9962> in <module>
#       6
#       7 df_weekend_days = df_general[df_general.DAY_OF_WEEK.isin(weekend_days)]
# ----> 8 df_week_days = df_week_days.drop('Unnamed: 0', 1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
df_weekend_days = df_general[df_general.DAY_OF_WEEK.isin(weekend_days)]
df_weekend_days = df_weekend_days.drop('Unnamed: 0', 1)

# %%
result_weekday = df_with_distance(df_week_days)
result_weekendday = df_with_distance(df_weekend_days)

result_weekday = Functions.position_measures(result_weekday)
result_weekendday = Functions.position_measures(result_weekendday)

result_weekday = Functions.normalization_values(result_weekday)
result_weekendday = Functions.normalization_values(result_weekendday)

# %%
x = np.arange(len(result_monday))
width = 0.35

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_weekday.index.values)


rects1 = ax.bar(x + width/2, result_weekday.HIGHER_MEAN, width, label='Week days')
rects2 = ax.bar(x - width/2, result_weekendday.HIGHER_MEAN, width, label='Weekend days')

autolabel(rects1)
autolabel(rects2)


plt.legend()
plt.title('Mean of Distance Travelled by region by week day and weekend day - HIGHER MEAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/higher_mean_week_weekend.jpg')

# %%
x = np.arange(len(result_monday))
width = 0.35

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_weekday.index.values)


rects1 = ax.bar(x + width/2, result_weekday.LOWER_MEAN, width, label='Week days')
rects2 = ax.bar(x - width/2, result_weekendday.LOWER_MEAN, width, label='Weekend days')

autolabel(rects1)
autolabel(rects2)


plt.legend()
plt.title('Mean of Distance Travelled by region by week day and weekend day - LOWER MEAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/lower_mean_week_weekend.jpg')

# %%
df_weekday_day = calls_of_day(df_week_days)
result_weekday_day = df_with_distance(df_weekday_day)
result_weekday_day = Functions.position_measures(result_weekday_day)
result_weekday_day = Functions.normalization_values(result_weekday_day)
# Out:
#                 LOWER_MEAN  HIGHER_MEAN  LOWER_MEDIAN  HIGHER_MEDIAN  \
# LD1               5.259840    83.656510      0.000000      56.647200
# MDM               3.917139    88.042352      0.000000      50.720500
# RT                0.204962    49.971624      0.000000      38.320400
# SJDR1             4.873431    17.359777      0.000000       7.895400
# SJDR2             5.589719    14.588034      0.000000       5.627700
# SJDR3             4.359542    23.244859      0.000000       8.410200
# SJDR4             3.260598    23.011681      0.000000       5.492100
# SJDR5             3.031982    15.999330      0.000000       5.125900
# ST               23.657100   100.542675      0.000000      94.989100
# SVM              10.752344   149.342123      0.000000     131.594600
# TR1               7.469970    23.312873      0.000000      17.388400
# TR2               5.910440     7.388050      3.439600       6.098200
# GENERAL_MEDIAN    6.523333    49.704167      0.286667      35.693333
#
# ...

# %%
x = np.arange(len(result_monday))
width = 0.35

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_weekday.index.values)


rects1 = ax.bar(x + width/2, result_weekday_day.HIGHER_MEAN, width, label='Week days')
rects2 = ax.bar(x - width/2, result_weekendday.HIGHER_MEAN, width, label='Weekend days')

autolabel(rects1)
autolabel(rects2)


plt.legend()
plt.title('Mean of Distance Travelled by region by week day during business hour and weekend day - HIGHER MEAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/higher_mean_week_weekend_with_bh.jpg')

# %%
x = np.arange(len(result_monday))
width = 0.35

fig, ax = plt.subplots(figsize=(20,8))

ax.set_xticks(x)
ax.set_xticklabels(result_weekday.index.values)


rects1 = ax.bar(x + width/2, result_weekday_day.LOWER_MEAN, width, label='Week days')
rects2 = ax.bar(x - width/2, result_weekendday.LOWER_MEAN, width, label='Weekend days')

autolabel(rects1)
autolabel(rects2)


plt.legend()
plt.title('Mean of Distance Travelled by region by week day during business hour and weekend day - LOWER MEAN')
plt.show()
fig.savefig('/home/gustavo/Desktop/Mestrado/mestrado_dados/metrics_by_weekday/lower_mean_week_weekend_with_bh.jpg')
